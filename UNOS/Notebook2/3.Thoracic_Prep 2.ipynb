# %%
from platform import python_version

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# set seaborn theme
sns.set_theme()

# print version
print("Numpy Version: " + np.__version__)
print("Pandas Version: " + pd.__version__)
print("Seaborn Version: " + sns.__version__)
print("Matplotlib Version: " + plt.matplotlib.__version__)
print("Python Version: " + python_version())

# adjust pandas display options to max
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# adjust pandas display options to ensure full display of content
pd.set_option('display.max_colwidth', None)
# Out:
# Numpy Version: 1.26.4
# Pandas Version: 2.2.3
# Seaborn Version: 0.13.2
# Matplotlib Version: 3.9.2
# Python Version: 3.9.20

# %%
# import pickle dataset
df = pd.read_pickle("../Data/cleanDF.pkl")

# %%
df.dtypes
# Out:
# NUM_PREV_TX                         int64
# THORACIC_DGN                        Int64
# GENDER                             object
# ABO                                object
# WGT_KG_TCR                        float64
# HGT_CM_TCR                        float64
# BMI_TCR                           float64
# CITIZENSHIP                         Int64
# PERM_STATE                         object
# EDUCATION                           Int64
# ECMO_TCR                            int64
# IABP_TCR                            int64
# INOTROPES_TCR                       int64
# PGE_TCR                             int64
# OTH_LIFE_SUP_TCR                    Int64
# VAD_DEVICE_TY_TCR                   Int64
# VAD_BRAND1_TCR                    float64
# FUNC_STAT_TCR                       Int64
# PRI_PAYMENT_TCR                     Int64
# TCR_DGN                             Int64
# DIAB                                Int64
# DIAL_TY_TCR                         Int64
# CEREB_VASC                         object
# MALIG_TCR                          object
# MOST_RCNT_CREAT                   float64
# TOT_SERUM_ALBUM                   float64
# IMPL_DEFIBRIL                      object
# HEMO_SYS_TCR                      float64
# HEMO_PA_DIA_TCR                   float64
# HEMO_PA_MN_TCR                    float64
# HEMO_PCW_TCR                      float64
# HEMO_CO_TCR                       float64
# INOTROP_VASO_SYS_TCR               object
# INOTROP_VASO_DIA_TCR               object
# INOTROP_VASO_MN_TCR                object
# INOTROP_VASO_PCW_TCR               object
# INOTROP_VASO_CO_TCR                object
# CIG_USE                            object
# TCR_DUR_ABSTAIN                     Int64
# PRIOR_CARD_SURG_TCR                object
# PRIOR_CARD_SURG_TYPE_TCR          float64
# PRIOR_CARD_SURG_TYPE_OSTXT_TCR     object
# DAYS_STAT1A                         int64
# DAYS_STAT2                          int64
# DAYS_STAT1B                         int64
# DAYS_STATA4                         int64
# DAYS_STATA5                         int64
# DAYS_STATA2                         int64
# DAYS_STATA3                         int64
# DAYS_STATA1                         int64
# DAYS_STATA6                         int64
# LAST_INACT_REASON                   Int64
# INIT_STAT                           Int64
# REM_CD                              Int64
# TXED                                Int64
# DAYSWAIT_CHRON                      int64
# END_STAT                            Int64
# INIT_AGE                            int64
# LIFE_SUP_TCR                       object
# ACTIVATE_DATE                      object
# END_DATE                           object
# INIT_DATE                          object
# ETHNICITY                           int64
# ETHCAT                              int64
# INIT_HGT_CM_CALC                  float64
# INIT_WGT_KG_CALC                  float64
# INIT_BMI_CALC                     float64
# END_HGT_CM_CALC                   float64
# END_WGT_KG_CALC                   float64
# END_BMI_CALC                      float64
# VENTILATOR_TCR                      int64
# REGION                              Int64
# VAL_DT_TCR                         object
# WORK_INCOME_TCR                    object
# BW4                                 int64
# BW6                                 int64
# C1                                  int64
# C2                                  int64
# DR51                                int64
# DR51_2                              int64
# DR52                                int64
# DR52_2                              int64
# DR53                                int64
# DR53_2                              int64
# DQ1                                 int64
# DQ2                                 int64
# FUNC_STAT_TRR                       Int64
# MED_COND_TRR                        Int64
# STATUS_TRR                         object
# ADMISSION_DATE                     object
# PRI_PAYMENT_TRR                     Int64
# ECMO_TRR                            int64
# PERM_STATE_TRR                     object
# WORK_INCOME_TRR                    object
# PGE_TRR                             int64
# CREAT_TRR                         float64
# DIAL_AFTER_LIST                    object
# HEMO_CO_TRR                       float64
# HEMO_PA_DIA_TRR                   float64
# HEMO_PA_MN_TRR                    float64
# HEMO_PCW_TRR                      float64
# HEMO_SYS_TRR                      float64
# IABP_TRR                            int64
# INFECT_IV_DRUG_TRR                 object
# INOTROPES_TRR                       int64
# INOTROP_VASO_CO_TRR                object
# INOTROP_VASO_DIA_TRR               object
# INOTROP_VASO_MN_TRR                object
# INOTROP_VASO_PCW_TRR               object
# INOTROP_VASO_SYS_TRR               object
# OTH_LIFE_SUP_TRR                    Int64
# PRIOR_LUNG_SURG_TRR                object
# PST_AIRWAY                         object
# ACUTE_REJ_EPI                       Int64
# PST_STROKE                         object
# PST_DIAL                           object
# PST_PACEMAKER                      object
# STEROID                            object
# TBILI                             float64
# TRANSFUSIONS                       object
# VAD_DEVICE_TY_TRR                   Int64
# VAD_BRAND1_TRR                    float64
# VENT_SUPPORT_TRR                   object
# VENTILATOR_TRR                      int64
# INHALED_NO_TRR                      int64
# PRIOR_CARD_SURG_TYPE_TRR          float64
# HBV_CORE                           object
# HBV_SUR_ANTIGEN                    object
# HBV_SURF_TOTAL                     object
# CMV_STATUS                         object
# HIV_SEROSTATUS                     object
# HCV_SEROSTATUS                     object
# EBV_SEROSTATUS                     object
# HIV_NAT                            object
# HCV_NAT                            object
# HBV_NAT                            object
# GSTATUS                             Int64
# GTIME                             float64
# LASTFUNO                            int64
# PSTATUS                             Int64
# PTIME                             float64
# PX_STAT                            object
# FUNC_STAT_TRF                       Int64
# STATUS_TCR                         object
# INHALED_NO_TCR                      int64
# DON_RETYP                          object
# CRSMATCH_DONE                      object
# CPRA                              float64
# CPRA_PEAK                         float64
# TRTREJ1Y                           object
# PREV_TX                            object
# PREV_TX_ANY                        object
# DA1_DON                           float64
# DA2_DON                           float64
# DB1_DON                           float64
# DB2_DON                           float64
# DDR1_DON                          float64
# DDR2_DON                          float64
# RA1                               float64
# RA2                               float64
# RB1                               float64
# RB2                               float64
# RDR1                              float64
# RDR2                              float64
# AMIS                                Int64
# BMIS                                Int64
# DRMIS                               Int64
# HLAMIS                              Int64
# PRAMR_CL1                         float64
# PRAMR_CL2                         float64
# MALIG_TRR                          object
# CMV_IGG                            object
# CMV_IGM                            object
# CITIZENSHIP_DON                     Int64
# HIST_COCAINE_DON                   object
# AGE_DON                           float64
# ETHCAT_DON                          int64
# HBV_CORE_DON                       object
# HBV_SUR_ANTIGEN_DON                object
# ABO_DON                            object
# ALCOHOL_HEAVY_DON                  object
# DON_TY                             object
# GENDER_DON                         object
# HOME_STATE_DON                     object
# HEP_C_ANTI_DON                     object
# NON_HRT_DON                        object
# ANTIHYPE_DON                       object
# BLOOD_INF_DON                       Int64
# BUN_DON                           float64
# CREAT_DON                         float64
# OTHER_INF_DON                     float64
# PT_DIURETICS_DON                   object
# PT_STEROIDS_DON                    object
# PT_T3_DON                          object
# PT_T4_DON                          object
# PT_OTH2_OSTXT_DON                  object
# PT_OTH3_OSTXT_DON                  object
# PT_OTH1_OSTXT_DON                  object
# PULM_INF_DON                        Int64
# SGOT_DON                          float64
# SGPT_DON                          float64
# TBILI_DON                         float64
# URINE_INF_DON                       Int64
# VASODIL_DON                        object
# VDRL_DON                           object
# CLIN_INFECT_DON                    object
# CONTIN_COCAINE_DON                 object
# CONTIN_OTH_DRUG_DON                object
# EXTRACRANIAL_CANCER_DON            object
# CANCER_SITE_DON                     Int64
# HIST_CIG_DON                       object
# HIST_HYPERTENS_DON                 object
# INTRACRANIAL_CANCER_DON            object
# HIST_CANCER_DON                    object
# HIST_DIABETES_DON                   Int64
# DIABETES_DON                       object
# HIST_OTH_DRUG_DON                  object
# SKIN_CANCER_DON                    object
# CMV_DON                            object
# COD_CAD_DON                         Int64
# DDAVP_DON                          object
# DEATH_CIRCUM_DON                    Int64
# DEATH_MECH_DON                      Int64
# RECOVERY_DATE_DON                  object
# HEPARIN_DON                        object
# ARGININE_DON                       object
# INSULIN_DON                        object
# HGT_CM_DON_CALC                   float64
# WGT_KG_DON_CALC                   float64
# BMI_DON_CALC                      float64
# HBV_NAT_DON                        object
# HCV_NAT_DON                        object
# HIV_NAT_DON                        object
# PX_STAT_DATE                       object
# TX_DATE                            object
# DISCHARGE_DATE                     object
# TX_TYPE                            object
# ABO_MAT                             Int64
# AGE                                 int64
# DIAG                                Int64
# DIAL_PRIOR_TX                      object
# ISCHTIME                          float64
# GRF_STAT                           object
# SHARE_TY                            int64
# LOS                               float64
# LIFE_SUP_TRR                       object
# PRIOR_CARD_SURG_TRR                object
# MALIG                              object
# HGT_CM_CALC                       float64
# WGT_KG_CALC                       float64
# BMI_CALC                          float64
# DISTANCE                          float64
# VENT_SUPPORT_AFTER_LIST            object
# PROC_TY_HR                          Int64
# VAL_DT_TRR                         object
# RECOV_OUT_US                       object
# ADMIT_DATE_DON                     object
# PROTEIN_URINE                      object
# CARDARREST_NEURO_DON               object
# PO2                               float64
# HIST_MI_DON                        object
# LV_EJECT_METH_DON                   Int64
# LV_EJECT_DON                      float64
# CORONARY_ANGIO                      Int64
# BIOPSY_DGN                          Int64
# TATTOOS_DON                        object
# STATUS_DDR                         object
# VAL_DT_DDR                         object
# HBSAB_DON                          object
# EBV_IGG_CAD_DON                    object
# EBV_IGM_CAD_DON                    object
# CDC_RISK_HIV_DON                   object
# INO_PROCURE_AGENT_1                 Int64
# ECD_DONOR                           Int64
# TX_YEAR                             int64
# INOTROP_SUPPORT_DON                object
# REFERRAL_DATE                      object
# LISTYR                              int64
# TRANSFUS_TERM_DON                   Int64
# PO2_DONE_DON                       object
# PO2_FIO2_DON                      float64
# PCO2_DON                          float64
# PULM_CATH_DON                      object
# BRONCHO_LT_DON                      Int64
# BRONCHO_RT_DON                      Int64
# CHEST_XRAY_DON                      Int64
# PH_DON                            float64
# HEMATOCRIT_DON                    float64
# dtype: object

# %% [markdown]
# ## Wrangle Dataset

# %%
print(f"There are total of {df.shape[0]:,} records and {df.shape[1]:,} features in the Heart Transplant Dataset.")
# Out:
# There are total of 27,494 records and 288 features in the Heart Transplant Dataset.

# %% [markdown]
# ### User Function(s)

# %%
def corrCols(df, threshold=0.9):
    """
    Determine highly correlated features
    """
    # initilaize variable
    feature = list()
    # calculate the correlation matrix
    correlation_matrix = df.select_dtypes(exclude='object').corr()
    
    # get the number of features
    num_features = correlation_matrix.shape[0]
    
    # iterate over the upper triangular part of the matrix
    for i in range(num_features):
        for j in range(i+1, num_features):
            feature1 = correlation_matrix.index[i]
            feature2 = correlation_matrix.columns[j]
            correlation = correlation_matrix.iloc[i, j]
            if abs(correlation) > threshold:
                feature.append(feature2)
                print(f"Correlation between {feature1} and {feature2}: {correlation:.3f}")

    return feature
    

def percentageNull(df):
    """
    Calculate percentage of NaN & NaN count
    """
    # calculate the percentage of non-null values for each column
    per_calc = pd.DataFrame(100 - (df.count() / len(df) * 100))
    
    # rename columns name
    per_calc.rename(columns={0: 'percentage'}, inplace=True)

    # add counter
    per_calc['NaNCount'] = df.isna().sum()
    
    # sort
    per_calc.sort_values(by='percentage', inplace=True, ascending=False)

    # 
    NanReturn = per_calc[per_calc.NaNCount != 0]
    
    return NanReturn


def plotBox(df, cols, width=14, height=10):
    # figure size
    plt.figure(figsize=(width, height))
    
    # iterate through each column and create a box plot
    for i, col in enumerate(cols, start=1):
        plt.subplot(3, 4, i)
        df.boxplot(column=col)
        plt.title(f'Boxplot of {col}')
        plt.ylabel(col)
    
    plt.tight_layout()
    plt.show()


def plotCount(df, cols, width=16, height=10, angle=False):
    # figure size
    plt.figure(figsize=(width, height))
    
    # assuming cols is your list of categorical columns
    for i, col in enumerate(cols, start=1):
        plt.subplot(3, 4, i)
        sns.countplot(data=df, x=col)
        plt.title(f'Countplot of {col}')
        plt.xlabel(col)
        if angle:
            plt.xticks(rotation=90) 
    
    plt.tight_layout()  # Adjust the layout
    plt.show()


def plotBar(df, cols, width=16, height=10, angle=False):
    # figure size
    plt.figure(figsize=(width, height))
    
    # assuming cols is your list of categorical columns
    for i, col in enumerate(cols, start=1):
        plt.subplot(3, 4, i)
        sns.barplot(data=df,x=df.index, y=col)
        plt.title(f'Barplot of {col}')
        plt.xlabel(col)
        if angle:
            plt.xticks(rotation=90) 
    
    plt.tight_layout()  # Adjust the layout
    plt.show()

# %% [markdown]
# ### Create Data Dictionary

# %%
# import Column description dataframe
colDef = pd.read_csv("../data/thoraticColumnNames.csv")

# current columns dataframe
dfColumns = pd.DataFrame(np.sort(df.columns.values), columns= ['featureName'])

# %%
# display random 5
colDef.sample(5)
# Out:
#                     featureName  \
# 303                      LISTYR
# 400                    PST_DIAL
# 23                BLOOD_INF_DON
# 338  OTH_DON_MED3_OSTXT_DON_OLD
# 530                  WL_ID_CODE
#
#                                                               desc  \
# 303            ACTUAL YEAR REGISTRANT LISTED (WITHOUT DATE OFFSET)
# 400                            EVENTS PRIOR TO DISCHARGE: DIALYSIS
# 23                        DECEASED DONOR-BLOOD AS INFECTION SOURCE
# 338  DECEASED DONOR OTHER MEDICATIONS3 W/IN 24 HRS PRE-CROSS CLAMP
# 530                              ENCRYPTED REGISTRATION IDENTIFIER
#
#            form         varStartDate           VarEndDate  \
# 303  CALCULATED  1987-10-01 00:00:00              Unknown
# 400         TRR  1994-04-01 00:00:00              Unknown
# 23          DDR  1994-04-01 00:00:00              Unknown
# 338         DDR  1994-04-01 00:00:00  2003-01-27 00:00:00
# 530  CALCULATED              Unknown              Unknown
#
#                               formSection dataType  \
# 303                               Unknown      NUM
# 400  POST TRANSPLANT CLINICAL INFORMATION     CHAR
# 23                   CLINICAL INFORMATION      NUM
# 338                  CLINICAL INFORMATION     CHAR
# 530                               Unknown      NUM
#
#                                                 labelSAS COMMENT
# 303  ACTUAL YEAR REGISTRANT LISTED (WITHOUT DATE OFFSET)  Unknown
# 400                       TRR DIALYSIS - POST TRANSPLANT  Unknown
# 23                            DDR INFECTION BLOOD SOURCE  Unknown
# 338               DDR OTHER MEDICATIONS3 PRE CROSS CLAMP  Unknown
# 530                                      ENCRYPTED WL_ID  Unknown

# %%
# display
dfColumns.head()
# Out:
#      featureName
# 0            ABO
# 1        ABO_DON
# 2        ABO_MAT
# 3  ACTIVATE_DATE
# 4  ACUTE_REJ_EPI

# %%
# shape of dataframe
dfColumns.shape, colDef.shape
# Out:
# ((288, 1), (545, 9))

# %%
# columns to rename
selectName = ['CARDARREST_NEURO', 'DDR1', 'DDR2', 'DA1', 'DA2', 'DB1', 'DB2', 'HIST_MI', 'LV_EJECT', 'LV_EJECT_METH', 'CPRA', 'TATTOOS']

# '|'.join(selectName) creates a regex pattern that matches strings in selectName - display
colDef[colDef['featureName'].str.contains('|'.join(selectName))]
# Out:
#           featureName  \
# 41   CARDARREST_NEURO
# 84               CPRA
# 85          CPRA_PEAK
# 94                DA1
# 95                DA2
# 110               DB1
# 111               DB2
# 113              DDR1
# 114              DDR2
# 235           HIST_MI
# 309          LV_EJECT
# 310     LV_EJECT_METH
# 456           TATTOOS
#
#                                                                   desc  \
# 41                      DECEASED DONOR-CARDIAC ARREST POST BRAIN DEATH
# 84                                          Recipient Most Recent CPRA
# 85                                                  RecipientPeak CPRA
# 94                                                    DONOR A1 ANTIGEN
# 95                                                    DONOR A2 ANTIGEN
# 110                                                   DONOR B1 ANTIGEN
# 111                                                   DONOR B2 ANTIGEN
# 113                                                  DONOR DR1 ANTIGEN
# 114                                                  DONOR DR2 ANTIGEN
# 235      DECEASED DONOR HISTORY OF PREVIOUS MI (MYOCARDIAL INFARCTION)
# 309                              DECEASED DONOR LV EJECTION FRACTION %
# 310  DECEASED DONOR LV EJECTION FRACTION METHOD: ECHO, MUGA, ANGIOGRAM
# 456                                              DECEASED DONOR-TATOOS
#
#            form         varStartDate VarEndDate  \
# 41          DDR  1999-10-25 00:00:00    Unknown
# 84           RH  2015-03-31 00:00:00    Unknown
# 85           RH  2015-03-31 00:00:00    Unknown
# 94   CALCULATED  1987-10-01 00:00:00    Unknown
# 95   CALCULATED  1987-10-01 00:00:00    Unknown
# 110  CALCULATED  1987-10-01 00:00:00    Unknown
# 111  CALCULATED  1987-10-01 00:00:00    Unknown
# 113  CALCULATED  1987-10-01 00:00:00    Unknown
# 114  CALCULATED  1987-10-01 00:00:00    Unknown
# 235         DDR  1999-10-25 00:00:00    Unknown
# 309         DDR  1999-10-25 00:00:00    Unknown
# 310         DDR  1999-10-25 00:00:00    Unknown
# 456         DDR  1999-10-25 00:00:00    Unknown
#
#                                 formSection dataType  \
# 41                     CLINICAL INFORMATION     CHAR
# 84                     CLINICAL INFORMATION      NUM
# 85                     CLINICAL INFORMATION      NUM
# 94   DONOR CENTER HISTOCOMPATIBILITY TYPING      NUM
# 95   DONOR CENTER HISTOCOMPATIBILITY TYPING      NUM
# 110  DONOR CENTER HISTOCOMPATIBILITY TYPING      NUM
# 111  DONOR CENTER HISTOCOMPATIBILITY TYPING      NUM
# 113  DONOR CENTER HISTOCOMPATIBILITY TYPING      NUM
# 114  DONOR CENTER HISTOCOMPATIBILITY TYPING      NUM
# 235          HEART DONOR'S CARDIAC FUNCTION     CHAR
# 309          HEART DONOR'S CARDIAC FUNCTION      NUM
# 310          HEART DONOR'S CARDIAC FUNCTION      NUM
# 456                           DONOR HISTORY     CHAR
#
#                                                    labelSAS COMMENT
# 41   DON CARDIAC ARR. SINCE EVENT THAT LED TO DECL OF DEATH  Unknown
# 84                                      RH Most Recent CPRA  Unknown
# 85                                             RH Peak CPRA  Unknown
# 94                                COMPUTED DONOR A1 ANTIGEN  Unknown
# 95                                COMPUTED DONOR A2 ANTIGEN  Unknown
# 110                               COMPUTED DONOR B1 ANTIGEN  Unknown
# 111                               COMPUTED DONOR B2 ANTIGEN  Unknown
# 113                              COMPUTED DONOR DR1 ANTIGEN  Unknown
# 114                              COMPUTED DONOR DR2 ANTIGEN  Unknown
# 235                              DON HISTORY OF PREVIOUS MI  Unknown
# 309                              DON LV EJECTION FRACTION %  Unknown
# 310                                              DON METHOD  Unknown
# 456                                             DON TATTOOS  Unknown

# %%
# list column definitions display from data
dfColumns[dfColumns['featureName'].str.contains('|'.join(selectName))]
# Out:
#               featureName
# 27   CARDARREST_NEURO_DON
# 43                   CPRA
# 44              CPRA_PEAK
# 48                DA1_DON
# 49                DA2_DON
# 60                DB1_DON
# 61                DB2_DON
# 63               DDR1_DON
# 64               DDR2_DON
# 142           HIST_MI_DON
# 184          LV_EJECT_DON
# 185     LV_EJECT_METH_DON
# 255           TATTOOS_DON

# %%
# map to rename
name_map = {'CARDARREST_NEURO':'CARDARREST_NEURO_DON', 'DA1': 'DA1_DON', 'DA2': 'DA2_DON', 'HIST_MI': 'HIST_MI_DON', 'LV_EJECT': 'LV_EJECT_DON', 
            'DB1':'DB1_DON', 'DB2':'DB2_DON', 'LV_EJECT_METH':'LV_EJECT_METH_DON','DDR1': 'DDR1_DON','DDR2': 'DDR2_DON','TATTOOS':'TATTOOS_DON'}

# Update the featureName column based on the mapping dictionary
colDef['featureName'] = colDef['featureName'].replace(name_map)

# %%
# join two DataFrames
dfColDef = pd.merge(colDef, dfColumns, how='right', on='featureName')

# display features in current DataFrame NOT in colDef 
dfColDef[dfColDef.desc.isna()]
# Out:
# Empty DataFrame
# Columns: [featureName, desc, form, varStartDate, VarEndDate, formSection, dataType, labelSAS, COMMENT ]
# Index: []

# %%
# shape column dictionary & Data
dfColDef.shape, df.shape
# Out:
# ((288, 9), (27494, 288))

# %%
# display random 5 rows
dfColDef.sample(5)
# Out:
#               featureName  \
# 202                   PO2
# 102         FUNC_STAT_TCR
# 27   CARDARREST_NEURO_DON
# 83                   DR53
# 9       ALCOHOL_HEAVY_DON
#
#                                                                 desc  \
# 202                                       DECEASED DONOR PO2 ON 100%
# 102                       RECIPIENT FUNCTIONAL STATUS @ REGISTRATION
# 27                    DECEASED DONOR-CARDIAC ARREST POST BRAIN DEATH
# 83   Candidate Most Recent/at Removal DR53 Antigen From Waiting List
# 9                            Heavy Alcohol Use (heavy=2+ drinks/day)
#
#                   form         varStartDate VarEndDate            formSection  \
# 202                DDR  1999-10-25 00:00:00    Unknown         ORGAN RECOVERY
# 102                TCR  1994-04-01 00:00:00    Unknown  CANDIDATE INFORMATION
# 27                 DDR  1999-10-25 00:00:00    Unknown   CLINICAL INFORMATION
# 83   WAITING LIST DATA  1987-10-01 00:00:00    Unknown      WAITING LIST DATA
# 9                  DDR  2004-06-30 00:00:00    Unknown      LIFESTYLE FACTORS
#
#     dataType                                                         labelSAS  \
# 202      NUM                                             DON LUNG PO2 ON 100%
# 102      NUM                                  TCR FUNCTIONAL STATUS @ LISTING
# 27      CHAR           DON CARDIAC ARR. SINCE EVENT THAT LED TO DECL OF DEATH
# 83       NUM  Candidate Most Recent/at Removal DR53 Antigen From Waiting List
# 9       CHAR                                    DDR HEAVY ALCOHOL USE (Y/N/U)
#
#     COMMENT
# 202  Unknown
# 102  Unknown
# 27   Unknown
# 83   Unknown
# 9    Unknown

# %% [markdown]
# #### Checking Data for NaNs

# %%
# NaN counts
NaNDf = percentageNull(df)

# list NaNs >= than 35%
NaNDf[NaNDf.percentage >= 35]
# Out:
#                                 percentage  NaNCount
# PRIOR_CARD_SURG_TYPE_OSTXT_TCR   78.871754     21685
# PRIOR_CARD_SURG_TYPE_TRR         77.929730     21426
# CONTIN_COCAINE_DON               77.736961     21373
# LAST_INACT_REASON                75.092748     20646
# PRAMR_CL2                        74.899978     20593
# PRAMR_CL1                        74.438059     20466
# TOT_SERUM_ALBUM                  73.205063     20127
# MALIG_TRR                        73.106860     20100
# CMV_IGM                          73.092311     20096
# CMV_IGG                          73.088674     20095
# PO2_DONE_DON                     72.517640     19938
# VAD_BRAND1_TCR                   71.186441     19572
# INO_PROCURE_AGENT_1              61.464319     16899
# PRIOR_CARD_SURG_TYPE_TCR         60.864189     16734
# VAD_BRAND1_TRR                   58.569142     16103
# TCR_DUR_ABSTAIN                  56.339565     15490
# HBV_NAT                          51.960428     14286
# HIV_NAT                          51.956791     14285
# HCV_NAT                          51.953153     14284
# BRONCHO_RT_DON                   50.421910     13863
# BRONCHO_LT_DON                   49.661744     13654
# CONTIN_OTH_DRUG_DON              44.198734     12152
# CPRA_PEAK                        43.838656     12053
# CPRA                             43.795010     12041
# PT_OTH3_OSTXT_DON                41.052593     11287

# %%
# re-index
dfColDef.reset_index(inplace=True, drop=True)

# missing data column description
dfColDef[dfColDef.featureName.str.contains('|'.join(NaNDf.index))].head()
# Out:
#           featureName  \
# 4       ACUTE_REJ_EPI
# 5      ADMISSION_DATE
# 6      ADMIT_DATE_DON
# 9   ALCOHOL_HEAVY_DON
# 10               AMIS
#
#                                                               desc  \
# 4   DID RECIPIENT HAVE ANY ACUTE REJECTION EPISODES PRE DISCHARGE?
# 5                         RECIPIENT DATE OF ADMISSION TO TX CENTER
# 6                                                 DONOR ADMIT DATE
# 9                          Heavy Alcohol Use (heavy=2+ drinks/day)
# 10                                          A LOCUS MISMATCH LEVEL
#
#           form         varStartDate VarEndDate  \
# 4          TRR  2004-06-30 00:00:00    Unknown
# 5          TRR  1999-10-25 00:00:00    Unknown
# 6          DDR  2006-04-26 00:00:00    Unknown
# 9          DDR  2004-06-30 00:00:00    Unknown
# 10  CALCULATED              Unknown    Unknown
#
#                              formSection dataType  \
# 4   POST TRANSPLANT CLINICAL INFORMATION      NUM
# 5                         PATIENT STATUS      NUM
# 6                      DONOR INFORMATION      NUM
# 9                      LIFESTYLE FACTORS     CHAR
# 10                               Unknown      NUM
#
#                               labelSAS COMMENT
# 4              ACUTE REJECTION EPISODE  Unknown
# 5   TRR DATE OF ADMISSION TO TX CENTER  Unknown
# 6                       DON ADMIT DATE  Unknown
# 9        DDR HEAVY ALCOHOL USE (Y/N/U)  Unknown
# 10              A LOCUS MISMATCH LEVEL  Unknown

# %%
# determine year & counts
df.TX_YEAR.value_counts().sort_values(ascending=False)
# Out:
# TX_YEAR
# 2021    3325
# 2020    3191
# 2019    3040
# 2018    2933
# 2017    2795
# 2016    2721
# 2015    2318
# 2014    2191
# 2013    2047
# 2012    1774
# 2011    1159
# Name: count, dtype: int64

# %%
# last five years
df_5 = df[df.TX_YEAR > 2016]
# shape
df_5.shape
# Out:
# (15284, 288)

# %%
# count NaNs
NaN_5 = percentageNull(df_5)
# display
NaN_5[NaN_5.percentage >= 40]
# Out:
#                                 percentage  NaNCount
# PO2_DONE_DON                    100.000000     15284
# CMV_IGM                         100.000000     15284
# CMV_IGG                         100.000000     15284
# MALIG_TRR                       100.000000     15284
# PRAMR_CL2                       100.000000     15284
# PRAMR_CL1                       100.000000     15284
# TOT_SERUM_ALBUM                  97.853965     14956
# PRIOR_CARD_SURG_TYPE_TRR         80.731484     12339
# PRIOR_CARD_SURG_TYPE_OSTXT_TCR   79.776237     12193
# LAST_INACT_REASON                76.478671     11689
# CONTIN_COCAINE_DON               73.985868     11308
# VAD_BRAND1_TCR                   71.918346     10992
# INO_PROCURE_AGENT_1              65.185815      9963
# PRIOR_CARD_SURG_TYPE_TCR         62.974352      9625
# VAD_BRAND1_TRR                   61.502225      9400
# TCR_DUR_ABSTAIN                  57.969118      8860
# BRONCHO_RT_DON                   51.903952      7933
# BRONCHO_LT_DON                   51.635697      7892
# PT_OTH3_OSTXT_DON                41.199948      6297

# %% [markdown]
# #### Excessive Missing Data

# %%
# remove features
removeCols = ['TX_YEAR', 'CMV_IGM', 'CMV_IGG', 'PRAMR_CL1', 'PO2_DONE_DON', 
              'PRAMR_CL2', 'MALIG_TRR'
             ]


# describe columns to be removed
df_5[removeCols].describe(include='all').T
# Out:
#                 count unique  top freq         mean       std     min     25%  \
# TX_YEAR       15284.0    NaN  NaN  NaN  2019.086234  1.412462  2017.0  2018.0
# CMV_IGM             0      0  NaN  NaN          NaN       NaN     NaN     NaN
# CMV_IGG             0      0  NaN  NaN          NaN       NaN     NaN     NaN
# PRAMR_CL1         0.0    NaN  NaN  NaN          NaN       NaN     NaN     NaN
# PO2_DONE_DON        0      0  NaN  NaN          NaN       NaN     NaN     NaN
# PRAMR_CL2         0.0    NaN  NaN  NaN          NaN       NaN     NaN     NaN
# MALIG_TRR           0      0  NaN  NaN          NaN       NaN     NaN     NaN
#
#                  50%     75%     max
# TX_YEAR       2019.0  2020.0  2021.0
# CMV_IGM          NaN     NaN     NaN
# CMV_IGG          NaN     NaN     NaN
# PRAMR_CL1        NaN     NaN     NaN
# PO2_DONE_DON     NaN     NaN     NaN
# PRAMR_CL2        NaN     NaN     NaN
# MALIG_TRR        NaN     NaN     NaN

# %%
# select columns for the dataframe
dfColDef = dfColDef.iloc[:, [0,1,2,5,6,7,8]][~dfColDef.featureName.str.contains('|'.join(removeCols))]

# shape
dfColDef.shape
# Out:
# (281, 7)

# %%
# remove columns
df_5 = df_5.drop(columns=removeCols)

# shape
df_5.shape
# Out:
# (15284, 281)

# %%
# count NaNs from new dataframe
NaN_5 = percentageNull(df_5)

# display 
NaN_5.head(10)
# Out:
#                                 percentage  NaNCount
# TOT_SERUM_ALBUM                  97.853965     14956
# PRIOR_CARD_SURG_TYPE_TRR         80.731484     12339
# PRIOR_CARD_SURG_TYPE_OSTXT_TCR   79.776237     12193
# LAST_INACT_REASON                76.478671     11689
# CONTIN_COCAINE_DON               73.985868     11308
# VAD_BRAND1_TCR                   71.918346     10992
# INO_PROCURE_AGENT_1              65.185815      9963
# PRIOR_CARD_SURG_TYPE_TCR         62.974352      9625
# VAD_BRAND1_TRR                   61.502225      9400
# TCR_DUR_ABSTAIN                  57.969118      8860

# %% [markdown]
# #### Examine `DATE` Features

# %%
# display descriptions
dateCols = df_5.columns[df_5.columns.str.contains('DATE')].values

# date column description
dfColDef[dfColDef.featureName.str.contains('|'.join(dateCols))]
# Out:
#            featureName  \
# 3        ACTIVATE_DATE
# 5       ADMISSION_DATE
# 6       ADMIT_DATE_DON
# 73      DISCHARGE_DATE
# 94            END_DATE
# 157          INIT_DATE
# 235       PX_STAT_DATE
# 242  RECOVERY_DATE_DON
# 244      REFERRAL_DATE
# 266            TX_DATE
#
#                                                                                                 desc  \
# 3                                                                     ALLOCATION TIME BEGINNING DATE
# 5                                                           RECIPIENT DATE OF ADMISSION TO TX CENTER
# 6                                                                                   DONOR ADMIT DATE
# 73                                                           RECIPIENT DISCHARGE DATE FROM TX CENTER
# 94   EARLIEST OF DATES OF REMOVAL FROM WAITING LIST, TRANSPLANT, DEATH, OR TIME COPY OF DATA CREATED
# 157                                                                  BEGINNING DATE FOR REGISTRATION
# 235                                                                            RECIPIENT STATUS DATE
# 242                                                                              ORGAN RECOVERY DATE
# 244                                                                            DATE OF REFERRAL CALL
# 266                                                                                  TRANSPLANT DATE
#
#                    form            formSection dataType  \
# 3     WAITING LIST DATA      WAITING LIST DATA      NUM
# 5                   TRR         PATIENT STATUS      NUM
# 6                   DDR      DONOR INFORMATION      NUM
# 73                  TRR         PATIENT STATUS      NUM
# 94    WAITING LIST DATA      WAITING LIST DATA      NUM
# 157   WAITING LIST DATA      WAITING LIST DATA      NUM
# 235  TRR/TRF-CALCULATED         PATIENT STATUS      NUM
# 242           DDR / LDR         ORGAN RECOVERY      NUM
# 244                 DDR   PROVIDER INFORMATION      NUM
# 266                 TRR  RECIPIENT INFORMATION      NUM
#
#                                    labelSAS  \
# 3                      WL LISTING BACK DATE
# 5        TRR DATE OF ADMISSION TO TX CENTER
# 6                            DON ADMIT DATE
# 73     TRR DATE OF DISCHARGE FROM TX CENTER
# 94             ENDING DATE FOR REGISTRATION
# 157         BEGINNING DATE FOR REGISTRATION
# 235  DATE OF DEATH, RE-TX OR LAST FOLLOW-UP
# 242              RECOVERY DATE (SENT TO OR)
# 244               DDR DATE OF REFERRAL CALL
# 266                     TRR TRANSPLANT DATE
#
#                                                                                                               COMMENT
# 3                                                                                                              Unknown
# 5                                                                                                              Unknown
# 6                                                                                                              Unknown
# 73                                                                                                             Unknown
# 94   IF PATIENT TRANSPLANTED OR DIED, BUT WAS REMOVED AFTER THE EVENT, END_DATE IS BACKDATED TO GIVE THE DATE OF EVENT
# 157                                                                                                            Unknown
# 235                                                                                                            Unknown
# 242                                                                                                            Unknown
# 244                                                                                                            Unknown
# 266                                                                                                            Unknown

# %%
# convert to dattime
df_5[dateCols] = df_5[dateCols].apply(pd.to_datetime)

# reset index
df_5.reset_index(inplace=True, drop=True)
dfColDef.reset_index(inplace=True, drop=True)

# %%
# full dataframe
df.to_pickle("../Data/cleanDF.pkl")

# cleaned dataframe save to pickle file
df_5.to_pickle("../Data/cleanDF_5_years.pkl")

# save to pickle file
dfColDef.to_pickle("../Data/columnDefinition.pkl")
